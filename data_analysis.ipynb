# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Илья, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# # Исследовательский анализ данных в Python и проверка гипотез

# %% [markdown]
# <h1>Оглавление проекта<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Исследовательский-анализ-данных-в-Python-и-проверка-гипотез" data-toc-modified-id="Исследовательский-анализ-данных-в-Python-и-проверка-гипотез-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Исследовательский анализ данных в Python и проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Цель-работы." data-toc-modified-id="Цель-работы.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Цель работы.</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Содержание-проекта" data-toc-modified-id="Содержание-проекта-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Содержание проекта</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-знакомство-с-ними" data-toc-modified-id="Загрузка-данных-и-знакомство-с-ними-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Загрузка данных и знакомство с ними</a></span></li><li><span><a href="#Предобработка-данных-и-подготовка-их-к-исследованию" data-toc-modified-id="Предобработка-данных-и-подготовка-их-к-исследованию-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Предобработка данных и подготовка их к исследованию</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-распределения-заказов-по-сегментам-и-их-сезонные-изменения" data-toc-modified-id="Анализ-распределения-заказов-по-сегментам-и-их-сезонные-изменения-1.3.3.1"><span class="toc-item-num">1.3.3.1&nbsp;&nbsp;</span>Анализ распределения заказов по сегментам и их сезонные изменения</a></span></li><li><span><a href="#Осенняя-активность-пользователей" data-toc-modified-id="Осенняя-активность-пользователей-1.3.3.2"><span class="toc-item-num">1.3.3.2&nbsp;&nbsp;</span>Осенняя активность пользователей</a></span></li><li><span><a href="#Популярные-события-и-партнёры" data-toc-modified-id="Популярные-события-и-партнёры-1.3.3.3"><span class="toc-item-num">1.3.3.3&nbsp;&nbsp;</span>Популярные события и партнёры</a></span></li></ul></li><li><span><a href="#Статистический-анализ-данных" data-toc-modified-id="Статистический-анализ-данных-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Статистический анализ данных</a></span></li><li><span><a href="#Общий-вывод-и-рекомендации" data-toc-modified-id="Общий-вывод-и-рекомендации-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Общий вывод и рекомендации</a></span></li></ul></li></ul></li><li><span><a href="#Комментарий-ревьюера:-общий-вывод-по-проекту." data-toc-modified-id="Комментарий-ревьюера:-общий-вывод-по-проекту.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Комментарий ревьюера: общий вывод по проекту.</a></span></li><li><span><a href="#Комментарий-ревьюера:-итоговый-вывод-по-проекту." data-toc-modified-id="Комментарий-ревьюера:-итоговый-вывод-по-проекту.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Комментарий ревьюера: итоговый вывод по проекту.</a></span></li></ul></div>

# %% [markdown]
# ## Цель работы.
# Выявить инсайты об изменении пользовательских предпочтений и популярности событий осенью 2024 года, а также проверить гипотезы о разнице в поведении пользователей с мобильными и стационарными устройствами.

# %% [markdown]
# ## Описание данных
# Данные о бронировании билетов на сервисе Яндекс Афиша за период с 1 июня по 30 ноября 2024 года, которые хранятся в двух датасетах: `final_tickets_orders_df.csv` и `final_tickets_events_df`.
# Первый датасет `final_tickets_orders_df.csv` включает информацию обо всех заказах билетов, совершённых с двух типов устройств — мобильных и стационарных:
# -  `order_id` — уникальный идентификатор заказа.
# -  `user_id` — уникальный идентификатор пользователя.
# -  `created_dt_msk` — дата создания заказа (московское время).
# -  `created_ts_msk` — дата и время создания заказа (московское время).
# -  `event_id` — идентификатор мероприятия из таблицы events.
# -  `cinema_circuit` — сеть кинотеатров. Если не применимо, то здесь будет значение 'нет'.
# -  `age_limit` — возрастное ограничение мероприятия.
# -  `currency_code` — валюта оплаты, например rub для российских рублей.
# -  `device_type_canonical` — тип устройства, с которого был оформлен заказ, например mobile для мобильных устройств, desktop для стационарных.
# -  `revenue` — выручка от заказа.
# -  `service_name` — название билетного оператора.
# -  `tickets_count` — количество купленных билетов.
# -  `total` — общая сумма заказа.
#
# В данные также был добавлен столбец `days_since_prev` с количеством дней с предыдущей покупки для каждого пользователя. Если покупки не было, то данные содержат пропуск.
# Второй датасет `final_tickets_events_df` содержит информацию о событиях, включая город и регион события, а также информацию о площадке проведения мероприятия. Были исключены фильмы, так как на дашборде, событий такого типа не так много. Датасет содержит такие поля:
# -  `event_id` — уникальный идентификатор мероприятия.
# -  `event_name` — название мероприятия. Аналог поля event_name_code из исходной базы данных.
# -  `event_type_description` — описание типа мероприятия.
# -  `event_type_main` — основной тип мероприятия: театральная постановка, концерт и так далее.
# -  `organizers` — организаторы мероприятия.
# -  `region_name` — название региона.
# -  `city_name` — название города.
# -  `venue_id` — уникальный идентификатор площадки.
# -  `venue_name` — название площадки.
# -  `venue_address` — адрес площадки.

# %% [markdown]
# ## Содержание проекта
# 1. Загрузка данных и знакомство с ними;
# 2. Предобработка данных и подготовка их к исследованию;
# 3. Исследовательский анализ данных;
#    3.1. Анализ распределения заказов по сегментам и их сезонные изменения;
#    3.2. Осенняя активность пользователей;
#    3.3. Популярные события и партнёры;
# 4. Статистический анализ данных;
# 5. Общий вывод и рекомендации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# ### Загрузка данных и знакомство с ними

# %%
pth1 = '/datasets/final_tickets_orders_df.csv'
pth2 = './datasets/final_tickets_orders_df.csv'

if os.path.exists(pth1):
    orders_df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    orders_df = pd.read_csv(pth2)
else:
    print('Something is wrong')

# %%
pth1 = '/datasets/final_tickets_events_df.csv'
pth2 = './datasets/final_tickets_events_df.csv'

if os.path.exists(pth1):
    events_df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    events_df = pd.read_csv(pth2)
else:
    print('Something is wrong')

# %%
pth1 = '/datasets/final_tickets_tenge_df.csv'
pth2 = './datasets/final_tickets_tenge_df.csv'

if os.path.exists(pth1):
    tenge_df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    tenge_df = pd.read_csv(pth2)
else:
    print('Something is wrong')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Отсутствует возможность загрузить данные с платформы Практикума.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Реализуй, пожалуйста, один из предложенных методов, чтобы код не падал при считывании данных во время запуска проекта на платформе.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Привет! Объясняю: локально у меня открывает только через точку, потому что относительный путь. Когда загружаю сюда с локалки он мне не дает изменить путь и убрать точки в начале.  Благодарен, что все равно проверил проект! Замечание исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Полезнее было бы всё же реализовать что-то из предложенного выше, чтобы работало одновременно и локально, и на платформе:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо! Исправил!
# </div>

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290849 entries, 0 to 290848
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               290849 non-null  int64
#  1   user_id                290849 non-null  object
#  2   created_dt_msk         290849 non-null  object
#  3   created_ts_msk         290849 non-null  object
#  4   event_id               290849 non-null  int64
#  5   cinema_circuit         290849 non-null  object
#  6   age_limit              290849 non-null  int64
#  7   currency_code          290849 non-null  object
#  8   device_type_canonical  290849 non-null  object
#  9   revenue                290849 non-null  float64
#  10  service_name           290849 non-null  object
#  11  tickets_count          290849 non-null  int64
#  12  total                  290849 non-null  float64
#  13  days_since_prev        268909 non-null  float64
# ...

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22427 entries, 0 to 22426
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                22427 non-null  int64
#  1   event_name              22427 non-null  object
#  2   event_type_description  22427 non-null  object
#  3   event_type_main         22427 non-null  object
#  4   organizers              22427 non-null  object
#  5   region_name             22427 non-null  object
#  6   city_name               22427 non-null  object
#  7   city_id                 22427 non-null  int64
#  8   venue_id                22427 non-null  int64
#  9   venue_name              22427 non-null  object
#  10  venue_address           22427 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.9+ MB

# %%
tenge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    130 non-null    object
#  1   curs    130 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# <i>Выводы:</i>
#
#    Объём данных датасета `orders_df` равен 31.1Мб, данные отображены корректно, тип данных для столбцов `created_dt_msk` и `created_dt_msk` стоит изменить на `datetime`, данные соответствуют описанию, пропусков наблюдаются в столбце `days_since_prev`, которые предусмотрены проектом, стоит отметить, что нужно проверить на наличие явных и неявных дубликатов.
#
#    Объём данных датасета `events_df` равен 1.9Мб, данные отображены корректно, данные не соответствуют описанию - присутствует столбец `city_id`, которого нет в описании, пропусков не наблюдается, также стоит отметить, что нужно проверить на наличие явных и неявных дубликатов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Первичное исследование данных выполнено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Относительно датасета `orders_df` вывод `пропусков не наблюдается` не совсем корректный - в признаке `days_since_prev` имеются пропуски. Скорректируй, пожлауйста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# В описании к работе проекта указано, что пропуски могут быть только как раз в этом солбце и я поэтому по умолчанию написал, что пропусков нет, подразумевая те, что нужно было бы заменять на значения или удалять строки с пропуском.
#     Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Предобработка данных и подготовка их к исследованию

# %% [markdown]
# Проверяем  столбцы с категориальными данными по датасету `orders_df`.

# %%
orders_df.groupby('cinema_circuit')['order_id'].count()
# Out:
# cinema_circuit
# Другое          1261
# КиноСити         122
# Киномакс           7
# Москино            7
# ЦентрФильм         1
# нет           289451
# Name: order_id, dtype: int64

# %%
orders_df.groupby('age_limit')['order_id'].count()
# Out:
# age_limit
# 0     61487
# 6     52173
# 12    62557
# 16    78579
# 18    36053
# Name: order_id, dtype: int64

# %%
orders_df.groupby('currency_code')['order_id'].count()
# Out:
# currency_code
# kzt      5069
# rub    285780
# Name: order_id, dtype: int64

# %%
orders_df.groupby('device_type_canonical')['order_id'].count()
# Out:
# device_type_canonical
# desktop     58170
# mobile     232679
# Name: order_id, dtype: int64

# %%
orders_df.groupby('service_name')['order_id'].count()
# Out:
# service_name
# Crazy ticket!               790
# Show_ticket                2200
# Билет по телефону            85
# Билеты без проблем        63709
# Билеты в интернете            4
# Билеты в руки             40364
# Быстробилет                2003
# Быстрый кассир              381
# Весь в билетах            16849
# Восьмёрка                  1118
# Вперёд!                      80
# Выступления.ру             1616
# Городской дом культуры     2733
# Дом культуры               4502
# Дырокол                      74
# За билетом!                2865
# Зе Бест!                      5
# КарандашРУ                  133
# Кино билет                   67
# Край билетов               6207
# Лимоны                        8
# Лови билет!               41126
# Лучшие билеты             17795
# Мир касс                   2167
# Мой билет                 34843
# Облачко                   26642
# Прачечная                 10273
# Радио ticket                376
# ...

# %% [markdown]
# По категориальным данным датасета `orders_df` мы видим, что значений, которые могут обозначать пропуски в данных или отсутствие информации нет. При этом стоит отметить, что по столбцу `cinema_circuit` присутствует значение `нет`, но мы понимаем, что это означает лишь то, что данное мероприятие не относится к сети кинотеатров. Это допустимо, и за пропуск считать не будем. Данные нормализованы.

# %% [markdown]
# Проверяем столбцы с категориальными данными по датасету `events_df`.

# %%
events_df.groupby('event_name')['event_id'].count()
# Out:
# event_name
# 000a9c8d-65bb-4178-a5a8-9ddc1f3bf71e    1
# 0015b11d-a3e0-4656-887a-383450a9b313    1
# 00298e1a-ae90-482b-819d-ba88ceff59b0    1
# 002c06bc-a677-4f50-9873-836ca0658603    1
# 002d57b9-d9ca-46a9-a4be-7b5c8685832e    2
#                                        ..
# ffe19736-c5f5-477d-ada2-e97cae12c51e    1
# ffed72f8-faf6-4784-af94-a9f82839a272    1
# fff20f2b-de72-451a-8168-b765352e502c    2
# fff68929-41eb-4dd7-90bf-76d3ae8b652f    1
# fffd87ef-5469-4684-af21-4f9b86a13189    1
# Name: event_id, Length: 15248, dtype: int64

# %%
events_df.groupby('event_type_main')['event_id'].count()
# Out:
# event_type_main
# выставки     290
# другое      4658
# концерты    8680
# спорт        872
# стендап      636
# театр       7076
# ёлки         215
# Name: event_id, dtype: int64

# %%
events_df.groupby('organizers')['event_id'].count()
# Out:
# organizers
# №1000    3
# №1001    2
# №1002    2
# №1003    1
# №1004    1
#         ..
# №995     1
# №996     2
# №997     2
# №998     6
# №999     3
# Name: event_id, Length: 4293, dtype: int64

# %%
events_df.groupby('region_name')['event_id'].count()
# Out:
# region_name
# Белоярская область        57
# Берестовский округ        39
# Берёзовская область      166
# Боровлянский край         97
# Верховинская область       8
#                         ...
# Шанырский регион          28
# Широковская область     1233
# Яблоневская область      535
# Ягодиновская область     120
# Яснопольский округ         5
# Name: event_id, Length: 81, dtype: int64

# %%
events_df.groupby('city_name')['event_id'].count()
# Out:
# city_name
# Айкольск        1
# Айсуак          1
# Акбастау       56
# Акбасты        83
# Акжолтау        1
#                ..
# Ясногородин     7
# Ясноград       27
# Яснолесье       2
# Яснополянск     1
# Ясносветск      2
# Name: event_id, Length: 352, dtype: int64

# %%
events_df.groupby('venue_name')['event_id'].count()
# Out:
# venue_name
# Академический ансамбль "Mirage" Лтд                1
# Академический ансамбль "Гардероб" Групп            1
# Академический ансамбль "Горизонт" и партнеры       1
# Академический ансамбль "Долго" Инкорпорэйтед       3
# Академический ансамбль "Задумка" Инкорпорэйтед     8
#                                                   ..
# Этнографический музей "Птица" Групп               31
# Этнографический музей "Светлый" Инк                1
# Этнографический музей "Сердце" Лтд                 5
# Этнографический музей "Синие" и партнеры           1
# Этнографический музей "Сказка" Лимитед             4
# Name: event_id, Length: 3217, dtype: int64

# %%
events_df.groupby('venue_address')['event_id'].count()
# Out:
# venue_address
# алл. 1 Мая, д. 3/4 стр. 4/5            1
# алл. 1 Мая, д. 32 стр. 46              1
# алл. 40 лет Октября, д. 1              7
# алл. 50 лет ВЛКСМ, д. 7                1
# алл. 50 лет Октября, д. 4/4 стр. 4     1
#                                       ..
# ш. Южное, д. 4/4 стр. 16               1
# ш. Южное, д. 6/9 к. 25                 1
# ш. Южное, д. 807                       1
# ш. Ярославское, д. 1 к. 8/9            1
# ш. Ярославское, д. 6/8                13
# Name: event_id, Length: 3225, dtype: int64

# %% [markdown]
# По категориальным значениям датасета `events_df` мы видим, что значений, которые могут обозначать пропуски в данных или отсутствие информации нет. При этом стоит отметить, что по столбцу `events_type_main` присутствует значение `другое`, но мы понимаем, что это означает лишь то, что данное мероприятие не относится ни к одной из существующих категорий. Это допустимо, и за пропуск считать не будем. Данные нормализованы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Категориальные признаки изучены. Вместо группировки и `count` или `value_counts` достаточно было бы использовать `nunique()` для анализа уникальных значений признаков.

# %% [markdown]
# Проверяем столбцы с количественным данными на распределение и наличие выбросов в датасете `orders_df`

# %% [markdown]
# Для начала разделим данные по валюте (`currency_code`)

# %%
bool_currency_code = orders_df['currency_code'] == 'rub'
orders_df_rub = orders_df[bool_currency_code].copy()
orders_df_kz = orders_df[~bool_currency_code].copy()

# %%
orders_df_rub['revenue'].describe()
# Out:
# count    285780.000000
# mean        547.568333
# std         871.524559
# min         -90.760000
# 25%         113.827500
# 50%         346.100000
# 75%         791.700000
# max       81174.540000
# Name: revenue, dtype: float64

# %%
orders_df_rub['tickets_count'].describe()
# Out:
# count    285780.000000
# mean          2.754077
# std           1.171419
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %%
bins = [0, 100, 200, 300, 400, 500, float('inf')]
labels = ['0-100', '100-200', '200-300', '300-400', '400-500', '500+']
orders_df_rub['revenue_group'] = pd.cut(orders_df_rub['revenue'], bins=bins, labels=labels)
orders_df_kz['revenue_group'] = pd.cut(orders_df_kz['revenue'], bins=bins, labels=labels)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на новое предупреждение - оно возникает из-за того, что срезы `orders_df_rub` и `orders_df_kz` были созданы не как копии, а как срезы из исходной таблицы, которые продолжают иметь с ними связь.
#
# Корректно делать новые переменные с помощью `copy()`:
#
#     orders_df_rub = orders_df[bool_currency_code].copy()
#     orders_df_kz = orders_df[~bool_currency_code].copy()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %%
plt.figure(figsize=(20, 6))
sns.countplot(data=orders_df_rub, x='revenue_group')
plt.xlabel('Диапазон выручки')
plt.ylabel('Выручка')
plt.title('Гистограмма распределения выручки, руб')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание на предупреждение - метод `plt.legend()` не находит объект, который мог бы использоваться в качестве легенды. Его можно передать непосредственно в `plt.legend()`, вроде `plt.legend(['Легенда'])`. Однако так как на графике только одна мера, подпись легенды необязательна.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай про подписи осей на графиках - тут и далее.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
orders_df_rub.boxplot(column='revenue')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, руб.')
plt.show()

# %%
bins = [0, 1, 2, 3, 4, 5, 6, float('inf')]
labels = ['0-1', '1-2', '2-3', '3-4', '4-5', '6', '6+']
orders_df_rub['tickets_count'] = pd.cut(orders_df_rub['tickets_count'], bins=bins, labels=labels)
sns.countplot(data=orders_df_rub, x='tickets_count')
plt.title('Распределение количества билетов по диапазонам')
plt.xlabel('Диапазон количества билетов')
plt.ylabel('Количество билетов')
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.countplot(data=orders_df_kz, x='revenue_group')
plt.xlabel('Диапазон выручки')
plt.ylabel('Выручка')
plt.title('Гистограмма распределения выручки, тенге')
plt.show()

# %%
orders_df_kz.boxplot(column='revenue')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, тенге')
plt.show()

# %%
sns.countplot(data=orders_df_kz, x='tickets_count')
plt.title('Распределение количества билетов по диапазонам')
plt.xlabel('Диапазон количества билетов')
plt.ylabel('Количество билетов')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для анализа распределения дискретных признаков не подходит обычная гистограмма - она оперирует корзинами, между которыми дискретные значения признаков могут распределяться неравномерно (это видно на графике, когда фигура смещена от цифры на оси Х влево или вправо). Для анализа распределения дискретных признаков нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
orders_df_kz.boxplot(column='tickets_count')
plt.xlabel('Количество билетов')
plt.title('Ящик с усами для определения выбросов по количеству билетов, ед.')
plt.show()

# %% [markdown]
# Отбираем значения по 99-процентилю выручку с заказа, так как имеются выбросы как по тенге, так и по рублю в столбце выручка, что мы видим по построенным ящикам с усами.

# %%
percentile99_rub = orders_df_rub['revenue'].quantile(0.99)
percentile99_kz = orders_df_kz['revenue'].quantile(0.99)
orders_df_rub = orders_df_rub[orders_df_rub['revenue'] <= percentile99_rub]
orders_df_kz = orders_df_kz[orders_df_kz['revenue'] <= percentile99_kz]

# %% [markdown]
# Проверим значения еще раз после того, как убрали выбросы по 99-процентилю.

# %%
orders_df_kz.boxplot(column='revenue')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, тенге')
plt.show()

# %%
orders_df_rub.boxplot(column='revenue')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, руб.')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Прокомментируй, пожалуйста, результаты анализа выбросов - сейчас у исследования нет анализа, и это снижает его ценность для конечного заказчика. Также обрати внимание на необходимость удаления явных выбросов:
#
#     Если найдутся выбросы в выручке с заказа revenue, то отберите значения по 99-му процентилю. Не забудьте, что данные изначально были представлены в разных валютах, поэтому разделите анализ на рубли и тенге.
#
# Выполни, пожалуйста, фильтрацию выбросов там, где необходимо.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил! НО: не должен ли я был эти выбросы посчитать в обобщенном датафрейме, где все привел к одной валюте по столбцу revenue_rub, так как толку что я здесь уберу выбросы, если дальше с датафреймами этими я не работаю нигде. Продублирую ту же работу для датафрейма general_df, созданного в конце раздела для дальнейшего анализа.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Да, верно, его нужно будет убрать и из основной таблицы.

# %% [markdown]
# Проверим явные дубликаты

# %%
orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
events_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Явных дубликатов нет.
# Проверяем на неявные дубликаты

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Дубликакты (явные и неявные) нужно проверять на уровне `orders_df`, так как в разрезе валют данные уже были изучены - в дальнейшем они уже не понадобятся.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
orders_df_rub['service_name'] = orders_df_rub['service_name'].str.lower().str.strip()

# %% [markdown]
# Неявных дубликатов не обнаружено. Изменим тип данных на дату для двух столбцов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Явные дубликаты проверены.

# %%
orders_df.duplicated(subset=['user_id', 'created_dt_msk', 'created_ts_msk', 'event_id', 'cinema_circuit', 'age_limit', 
                   'currency_code', 'device_type_canonical', 'revenue', 'service_name', 'tickets_count', 'total']).sum()
# Out:
# np.int64(40)

# %% [markdown]
# Мы получили 40 неявных дубликатов по всем строкам датафрейма. Удалим дубликаты записей.

# %%
orders_df.drop_duplicates(subset=['user_id', 'created_dt_msk', 'created_ts_msk', 'event_id', 'cinema_circuit', 'age_limit', 
                   'currency_code', 'device_type_canonical', 'revenue', 'service_name', 'tickets_count', 'total'])
# Out:
#         order_id          user_id           created_dt_msk  \
# 0        4359165  0002849b70a3ce2  2024-08-20 00:00:00.000
# 1        7965605  0005ca5e93f2cf4  2024-07-23 00:00:00.000
# 2        7292370  0005ca5e93f2cf4  2024-10-06 00:00:00.000
# 3        1139875  000898990054619  2024-07-13 00:00:00.000
# 4         972400  000898990054619  2024-10-04 00:00:00.000
# ...          ...              ...                      ...
# 290844    368620  fffcd3dde79eb2c  2024-10-27 00:00:00.000
# 290845    368562  fffcd3dde79eb2c  2024-10-27 00:00:00.000
# 290846   8473772  fffcd3dde79eb2c  2024-10-30 00:00:00.000
# 290847   5526067  fffeeb3c120cf0b  2024-09-24 00:00:00.000
# 290848    813654  ffff00725179321  2024-09-25 00:00:00.000
#
#                  created_ts_msk  event_id cinema_circuit  age_limit  \
# 0       2024-08-20 16:08:03.000    169230            нет         16
# 1       2024-07-23 18:36:24.000    237325            нет          0
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание, что неявные дубликаты - это не только анализ уникальных значений категориальных признаков (его мы уже сделали ранее - тут можно было не дублировать), но и дубликаты, которые появляются при удалении идентификатора. Проверь наличие дубликатов в `orders_df` без учёта идентификатора заказа `order_id`. Если дубликаты будут - нужно будет изучить их и принять решение о их дальнейшей обработке.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
orders_df['created_dt_msk'] = pd.to_datetime(orders_df['created_dt_msk'])
orders_df['created_ts_msk'] = pd.to_datetime(orders_df['created_ts_msk'])

# %%
tenge_df['data'] = pd.to_datetime(tenge_df['data'], dayfirst=True)
orders_df = orders_df.merge(tenge_df, left_on='created_dt_msk', right_on='data', how='left')

def transit_currency_code(x):
    if x['currency_code'] == 'rub':
        return x['revenue']
    else:
        return x['revenue']*x['curs'] / 100

orders_df['revenue_rub'] = orders_df.apply(transit_currency_code, axis=1)

# %%
orders_df['one_ticket_revenue_rub'] = orders_df['revenue_rub'] / orders_df['tickets_count']

# %%
orders_df['month'] = orders_df['created_dt_msk'].dt.month

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return 'зима'
    elif month in [3, 4, 5]:
        return 'весна'
    elif month in [6, 7, 8]:
        return 'лето'
    else:
        return 'осень'

orders_df['season'] = orders_df['month'].apply(get_season)

# %%
general_df = orders_df.merge(events_df, on='event_id', how='inner')

# %%
general_df.boxplot(column='revenue_rub')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, руб.')
plt.show()

# %%
percentile99 = general_df['revenue'].quantile(0.99)
general_df = general_df[general_df['revenue'] <= percentile99_rub]

# %%
general_df.boxplot(column='revenue_rub')
plt.xlabel('Выручка')
plt.title('Ящик с усами для определения выбросов по выручке, руб.')
plt.show()

# %% [markdown]
# <i>Выводы:</i>
# По итогам предобработки мы поменяли типы данных у столбцов, которые имеют дату. Исключили выбросы по столбцу `revenue`. Объединили два датафрейма по полю `event_id`. Добавили 4 новых столбца, которые помогут нам в исследовательском анализе данных: провели категоризацию по месяцам (`month`) и сезонам(`season`): зима, весна, лето и осень. Рассчитали выручку на покупку одного билета с одного мероприятия (`one_ticket_revenue_rub`). И создали столбец, в котором привели валюту к единообразию - к рублю (`revenue_rub`).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Новые признаки выделены корректно.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Анализ распределения заказов по сегментам и их сезонные изменения

# %% [markdown]
# Для каждого месяца найдем количество заказов и визуализируем их.

# %%
df_months = general_df.groupby('month')['order_id'].count().sort_values()
df_months = df_months.reset_index()
df_months.plot(
    kind='bar',
    title='Диаграмма распределения количества заказов по месяцам',
    legend=False,
    x='month',
    y='order_id',
    xlabel='Месяц',
    ylabel='Количество заказов',
    rot=0
)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Технические комментарии типа `<AxesSubplot:xlabel='datetime'>` стоит убирать - это можно сделать, поставив точку с запятой в последней строке кода в блоке визуализации, либо сделать последней строкой кода этого блока метод `plt.show()`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
#  Фиксируется увеличение заказов от июня к ноябрю 2024 года.

# %% [markdown]
# Для осеннего и летнего периодов сравним распределение заказов билетов по типу мероприятия.

# %%
df_seasons_device_type = (
    general_df.groupby(['season', 'event_type_main'])['order_id']
    .count()
    .div(general_df.groupby('season')['order_id'].count(), level=0)
    .mul(100)
    .reset_index(name='percentage')
)

# %%
pivot_df = df_seasons_device_type.pivot(
    index='season', 
    columns='event_type_main', 
    values='percentage'
)
pivot_df.plot(
kind='bar',
figsize=(15, 10),
rot=0,
legend=True,
title='Доля заказов по каждому типу мероприятия и по сезону',
xlabel='Тип мероприятия',
ylabel='Доля заказов'
)
plt.show()

# %%
pivot_df.head(5)
# Out:
# event_type_main  выставки     другое   концерты      спорт   стендап  \
# season
# лето             2.074411  27.729477  41.386946   2.578209  5.443934
# осень            1.447682  19.735661  37.078131  11.221318  4.114246
#
# event_type_main      театр      ёлки
# season
# лето             20.552719  0.234305
# осень            25.398023  1.004939

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут и далее обрати внимание на значения оси Y - если доли посчитаны корректно, значения по оси Y не могут быть выше 100.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> График будет проще читать без `stacked=True`, также удобнее будет сделать `season` столбцами.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Для осеннего и летнего периодов сравним распределение заказов билетов по типу устройства.

# %%
df_seasons_device_type = (
    general_df.groupby(['season', 'device_type_canonical'])['order_id']
    .count()
    .div(general_df.groupby('season')['order_id'].count(), level=0)
    .mul(100)
    .reset_index(name='percentage')
)

pivot_df = df_seasons_device_type.pivot(
    index='season', 
    columns='device_type_canonical', 
    values='percentage'
)
pivot_df.plot(
kind='bar',
figsize=(15, 10),
rot=0,
legend=True,
title='Доля заказов по каждому типу устройства и по сезону',
xlabel='Тип устройства',
ylabel='Доля заказов'
)
plt.show()

# %% [markdown]
# Для осеннего и летнего периодов сравним распределение заказов билетов по возрастному цензу.

# %%
df_seasons_age_limit = (
    general_df.groupby(['season', 'age_limit'])['order_id']
    .count()
    .div(general_df.groupby('season')['order_id'].count(), level=0)
    .mul(100)
    .reset_index(name='percentage')
)

pivot_df = df_seasons_age_limit.pivot(
    index='season', 
    columns='age_limit', 
    values='percentage'
)

pivot_df.plot(
kind='bar',
figsize=(15, 10),
rot=0,
stacked=True,
legend=True,
title='Доля заказов по каждому типу устройства и по сезону',
xlabel='возрастной ценз',
ylabel='Доля заказов'
)
plt.show()

# %% [markdown]
# <i>Выводы:</i>
# По всем показателям количество к осени растет. Стоит отметить более высокий спрос на концерты относительно остальных показателей по типу мероприятий. Также мы видим, как сильно превалирует значение показателя по типу устройств - мобильный над десктопным. По возрастному цензу мы видим, что чаще всего публикуются мероприятия 16+ - летом, при этом к осени заметно увеличилось количество мероприятий с цензом 0+ и 12+. При этом ценз 18+ можно сказать, что не зависит от сезонности.

# %% [markdown]
# #### Осенняя активность пользователей

# %% [markdown]
# Проанализируем динамику изменений по дням для:
# общего числа заказов;
# количества активных пользователей DAU;
# среднего числа заказов на одного пользователя;
# средней стоимости одного билета.

# %%
daily_stats = general_df.groupby('created_dt_msk').agg(
    total_orders=('order_id', 'count'),
    dau=('user_id', 'nunique'),
    avg_revenue=('revenue_rub', 'mean'),
    total_revenue = ('revenue_rub', 'sum'),
    total_tickets = ('tickets_count', 'sum')
    
).reset_index()

daily_stats['orders_per_user'] = daily_stats['total_orders'] / daily_stats['dau']
daily_stats['avg_ticket'] = daily_stats['total_revenue'] / daily_stats['total_tickets']

# %%
plt.figure(figsize=(15, 5))
plt.plot(daily_stats['created_dt_msk'], daily_stats['total_orders'], label='Заказы', marker='o')
plt.xlabel('Дата')
plt.ylabel('Количество')
plt.legend()
plt.grid()
plt.title('Динамика заказов')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(daily_stats['created_dt_msk'], daily_stats['dau'], label='DAU', marker='s')
plt.xlabel('Дата')
plt.ylabel('Количество')
plt.legend()
plt.grid()
plt.title('Динамика активных пользователей')
plt.show()

# %% [markdown]
# Имеется общий тренд роста как количества заказов, так и активных пользователей за отчетный период. При этом стоит отметить экстремумы некоторых значений, что может говорить скорей всего о разовых массовых мероприятиях, например, фестивалях или гала-концертах.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Метрики с разным масштабом значений будет удобнее разделять на отдельные графики, чтобы их было проще интерпретировать.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
plt.figure(figsize=(10, 5))
plt.plot(daily_stats['created_dt_msk'], daily_stats['avg_revenue'], label='Средний чек', marker='o', color='green')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.legend()
plt.grid()
plt.title('Динамика среднего чека')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(daily_stats['created_dt_msk'], daily_stats['orders_per_user'], label='Заказов на пользователя', marker='s', color='red')
plt.xlabel('Дата')
plt.ylabel('Значение')
plt.legend()
plt.grid()
plt.title('Динамика заказов на пользователя')
plt.show()

# %% [markdown]
# Есть значение по одному экстремуму в июне, сентябре и октябре по среднему чеку, при этом общий тренд не определяется как по резкому росту, так и по резкому снижению, но при этом наблюдается плавное снижение среднего чека к ноябрю 2024 года.
# При этом количество заказов на одного пользователя растет. Имеются экстремумы в сентябре и октябре, что приходится на самый пик сезона концертов и театров.

# %%
plt.figure(figsize=(15, 5))
plt.plot(daily_stats['created_dt_msk'], daily_stats['avg_ticket'], label='Билет', marker='o')
plt.xlabel('Дата')
plt.ylabel('Средняя стоимость билета')
plt.legend()
plt.grid()
plt.title('Динамика средней стоимости билета')
plt.show()

# %% [markdown]
# При этом наблюдаем снижение общего тренда средней стоимости одного билета. В те же дни, где было большое количество заказов и снижение среднего чека (экстремумы), мы наблюдаем более низкую цену на билет.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Вот здесь метрики явно стоит разделить, так как заказы на пользователя представлены в виде идущей строго прямо линии.
#
# 2. Также не исследована стоимость одного билета.
#
# 3. По двум графикам выше не хватает выводов - добавь, пожалуйста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Изучим недельную цикличность.

# %%
general_df['day_of_week'] = general_df['created_dt_msk'].dt.day_name()

# %%
weekly_stats = general_df.groupby('day_of_week').agg(
    total_orders=('order_id', 'count'),
    dau=('user_id', 'nunique'),
    avg_revenue=('revenue_rub', 'mean')
).reset_index().sort_values(by='day_of_week')

weekly_stats['orders_per_user'] = weekly_stats['total_orders'] / weekly_stats['dau']

# %%
plt.figure(figsize=(15, 5))
plt.plot(weekly_stats['day_of_week'], weekly_stats['total_orders'], label='Заказы', marker='o')
plt.plot(weekly_stats['day_of_week'], weekly_stats['dau'], label='DAU', marker='s')
plt.title('Активность по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество')
plt.legend()
plt.grid()
plt.show()

# %%
weekly_stats['avg_revenue'].sort_values().plot(
    kind='bar', 
    color=['skyblue', 'orange'],
    title='Средний чек',
    xlabel='Дни недели',
    ylabel='Средний чек',
    rot=0
)
plt.show()

# %% [markdown]
# <i>Выводы:</i>
# Стоит отметить более высокий пик активности со вторника по пятницу и спад активности в выходные дни.

# %% [markdown]
# #### Популярные события и партнёры

# %% [markdown]
# Для каждого региона посчитаем уникальное количество мероприятий и общее число заказов.

# %%
df_region_events_total = general_df.groupby('region_name').agg(
    orders_count=('order_id', 'count'),
    events_count=('venue_id', 'nunique')).sort_values(by='events_count', ascending=False).reset_index()
df_region_events_total[df_region_events_total['events_count'] == 7].count()
df_region_events_total['orders_count_share'] = df_region_events_total['orders_count']/general_df['order_id'].count()
df_region_events_total['venue_count_share'] = df_region_events_total['events_count']/general_df['venue_id'].count()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Количество мероприятий нужно считать по `venue_id`, а не по `event_type_main`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
df_region_events_total.head(17)
# Out:
#                   region_name  orders_count  events_count  orders_count_share  \
# 0          Каменевский регион         89669           733            0.314867
# 1        Североярская область         43744           479            0.153604
# 2        Светополянский округ          7503           178            0.026346
# 3         Широковская область         16169           173            0.056776
# 4        Тепляковская область          4385           111            0.015398
# 5            Травяная область          5036           107            0.017684
# 6   Солнечнореченская область          3977            94            0.013965
# 7         Речиновская область          6267            86            0.022006
# 8        Горицветская область          5153            84            0.018094
# 9           Медовская область         13895            82            0.048791
# 10       Серебринская область          5586            79            0.019615
# ...

# %% [markdown]
# Мы видим, что 15 регионов имеют максимальное количество разнообразных мероприятий.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Помимо абсолютных величин, стоит добавить в анализ относительные величины, как сказано в условии проекта.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
df_region_events_total = (
    general_df.groupby('region_name')['order_id']
    .count()
    .div(general_df.groupby('region_name')['order_id'].count(), level=0)
    .mul(100)
    .reset_index(name='percentage')
)

# %%
df_region_events_total.head(17)
# Out:
#               region_name  percentage
# 0      Белоярская область       100.0
# 1      Берестовский округ       100.0
# 2     Берёзовская область       100.0
# 3       Боровлянский край       100.0
# 4    Верховинская область       100.0
# 5       Верхозёрский край       100.0
# 6     Верхоречная область       100.0
# 7       Ветренский регион       100.0
# 8         Вишнёвский край       100.0
# 9    Глиногорская область       100.0
# 10      Голубевский округ       100.0
# 11   Горицветская область       100.0
# 12    Горноземский регион       100.0
# 13    Горностепной регион       100.0
# 14  Дальнеземская область       100.0
# 15     Дальнезорский край       100.0
# 16      Дубравная область       100.0

# %% [markdown]
# Для каждого билетного партнёра посчитаем общее число уникальных мероприятий, обработанных заказов и суммарную выручку с заказов билетов.

# %%
df_organizers = general_df.groupby('service_name').agg(
    events_count=('venue_id', 'nunique'),
    orders_count=('order_id', 'count'),
    revenue_sum=('revenue', 'sum')
    ).sort_values(by='revenue_sum', ascending=False).reset_index()
df_organizers['revenue_sum'] = df_organizers['revenue_sum'].round(2)
df_organizers.head(10)
# Out:
#          service_name  events_count  orders_count  revenue_sum
# 0  Билеты без проблем           872         62528  24444547.92
# 1             Облачко           688         26402  18588613.86
# 2           Мой билет           391         31859  18438509.42
# 3         Лови билет!           714         40804  16670657.83
# 4      Весь в билетах           298         16410  16494669.19
# 5       Билеты в руки           897         40286  13194887.80
# 6        Край билетов            68          6109   6405689.22
# 7           Прачечная           183         10222   4746810.52
# 8        Дом культуры           109          4412   4358655.99
# 9              Яблоко           288          5004   3868336.88

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Агрегировать данные нужно по `service_name`: `organizers` - это не билетный партнёр, а организатор мероприятия.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание, что ранее уже было замечание по мероприятиям - их нужно считать по `venue_id`, а не по `event_type_main`. Также значения в `revenue_sum` стоит перевести их экспоненциальной формы записи в обычную - это можно сделать округлением `round()`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Стоит отметить, что при неполном разнообразии типов мероприятий (до 3) организаторы имеют бОльшую выручку.

# %% [markdown]
# ### Статистический анализ данных

# %% [markdown]
# Подготовим данные за осенний период для проверки гипотез

# %%
autumn_df = general_df[general_df['month'].isin([9, 10, 11])]

# %% [markdown]
# Гипотеза 1: Среднее количество заказов на пользователя выше у мобильных пользователей
# Формулировка гипотез:
# H0: Среднее количество заказов у мобильных не выше, чем у десктопных пользователей.
# H1: Среднее количество заказов у мобильных пользователей выше.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Гипотезы сформулированы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> При работе с односторонними гипотезами нулевая гипотеза формулируется от обратного к альтернативной. Если альтернативная - `выше`, то нулевая должна быть `не выше`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
orders_per_user = autumn_df.groupby(['user_id','device_type_canonical'])['order_id'].count().reset_index()
mobile_orders = orders_per_user[orders_per_user['device_type_canonical'] == 'mobile']['order_id'].reset_index()
desktop_orders = orders_per_user[orders_per_user['device_type_canonical'] == 'desktop']['order_id'].reset_index()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#     Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
sns.boxplot(x='device_type_canonical', y='order_id', data=orders_per_user)
plt.title('Распределение заказов на пользователя')
plt.show()

# %%
mobile_orders['order_id'].var()
# Out:
# np.float64(4640.810816661148)

# %%
desktop_orders['order_id'].var()
# Out:
# np.float64(1299.2497128327022)

# %% [markdown]
# Из-за наличия обильного числа выбросов и различий дисперсий применяем тест Манна-Уитни.

# %%
result = st.mannwhitneyu(
    mobile_orders['order_id'],
    desktop_orders['order_id'],
    alternative='greater')

alpha = 0.05

if result.pvalue < alpha:
    print(f'Отвергаем нулевую гипотезу!pvalue={result.pvalue}')
else:
    print(f'Не получилось отвергнуть нулевую гипотезу!pvalue={result.pvalue}')
# Out:
# Отвергаем нулевую гипотезу!pvalue=4.7539650151092243e-07

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Тест проведён корректно.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание, что по условию проекта важно обосновать выбор теста.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `У нас нет выбросов` - на графике выше мы как раз видим выбросы в обильном количестве - это может быть аргументом для применения теста Манна-Уитни:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202025-03-30%20%D0%B2%2011.45.01.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202025-03-30%20%D0%B2%2011.45.01.png)
#
# Скорректируй, пожалуйста, обоснование теста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Гипотеза 2. Среднее время между заказами пользователей мобильных приложений выше по сравнению с пользователями стационарных устройств.
# H0: Среднее время между заказами у мобильных не больше, чем у десктопных пользователей.
# H1: Среднее время между заказами у мобильных пользователей больше.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут также нужно скорректировать формулировку гипотез.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
autumn_df = autumn_df.sort_values(['user_id', 'created_dt_msk'])
autumn_df = autumn_df.dropna(subset=['days_since_prev'])
mobile_time = autumn_df[autumn_df['device_type_canonical'] == 'mobile']['days_since_prev']
desktop_time = autumn_df[autumn_df['device_type_canonical'] == 'desktop']['days_since_prev']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Рассчитывать разницу руками не нужно - у нас ест признак `days_since_prev`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
mobile_time.var()
# Out:
# np.float64(178.6335392720675)

# %%
desktop_time.var()
# Out:
# np.float64(145.47912695929722)

# %% [markdown]
# Из-за наличия обильного числа выбросов и различий дисперсий применяем тест Манна-Уитни.

# %%
result = st.mannwhitneyu(
    mobile_time,
    desktop_time,
    alternative='greater')

alpha = 0.05

if result.pvalue < alpha:
    print(f'Отвергаем нулевую гипотезу!pvalue={result.pvalue}')
else:
    print(f'Не получилось отвергнуть нулевую гипотезу!pvalue={result.pvalue}')
# Out:
# Отвергаем нулевую гипотезу!pvalue=1.2565720449641634e-93

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати внимание на значение `p-value`, равное `nan` - оно получено из-за наличия пропусков в исследуемом признаке. Удали их для корректного расчёта `p-value`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут по аналогии с первой гипотезой также нужно обосновать выбор теста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Общий вывод и рекомендации

# %% [markdown]
# Объём данных датасета orders_df равен 31.1Мб, данные отображены корректно, тип данных для столбцов created_dt_msk и created_dt_msk стоит изменить на datetime, данные соответствуют описанию, пропусков не наблюдается, также стоит отметить, что нужно проверить на наличие явных и неявных дубликатов. Данные нормализованы.
#
# Объём данных датасета events_df равен 1.9Мб, данные отображены корректно, данные не соответствуют описанию - присутствует столбец city_id, которого нет в описании, пропусков не наблюдается, также стоит отметить, что нужно проверить на наличие явных и неявных дубликатов. Данные нормализованы.
# Два датасета были объединены в единый датасет general_df для удобного проведения исследовательского анализа.
#
# Основные результаты анализа: наиболее популярные мероприятия - это концерты, осенью популярность мероприятий возросла, стоимость среднего чека также возросла. Чаще всего пользователи посещали мероприятия со вторника по пятницу. Среди регионов и партнёров есть явные лидеры по числу заказов и выручке с продажи билетов: №4950 (22,2 млн руб.).
#
# Стоит отметить более высокий спрос на концерты относительно остальных показателей по типу мероприятий. Также мы видим, как сильно превалирует значение показателя по типу устройств - мобильный над десктопным. По возрастному цензу мы видим, что чаще всего публикуются мероприятия 16+ - летом, при этом к осени заметно увеличилось количество мероприятий с цензом 0+ и 12+. При этом ценз 18+ можно сказать, что не зависит от сезонности.
#
# Результаты проверки гипотез показывают нам то, что среднее количество заказов у мобильных устройств выше, чем у десктопных, а значит нужно больше уделять внимание пользовательскому интерфейсу мобильных устройств, так как там больше клиентов, использующих приложение.
#
# Результаты проверки второй гипотезы показывают, что среднее время между заказами у мобильных приложений больше, чем у десктопных.
#
# Рекомендации: Совершенствовать мобильное приложение.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хороший промежуточный вывод - кратко описаны основные результаты исследовательской части и проверки гипотез.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> По поводу второй гипотезы выше оставил замечание - его исправление поможет получить корректный результат. Также рекомендация `Совершенствовать мобильное приложение` слишком широкая - для такой рекомендации можно было не проводить аналитическое исследование. Стоит сделать более конкретную рекомендацию, опираясь на результаты работы над каким-либо из этапов проекта.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В части исправлений по проекту не забудь скорректировать выводы.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Илья, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Илья, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейших начинаниях:)
